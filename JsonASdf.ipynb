# %%
# Import libraries
import pandas as pd
import json
import numpy as np
import requests

# %%
# Import libraries
from dotenv import load_dotenv
import os
import base64
from requests import post, get

# %%
# read the JSON file
print ("Read Dataset...")
def read_dataset(path):
    return json.load(open(path))

data = read_dataset('RAsongs.json')
# Out:
# Read Dataset...

# %%
# Json daata orginized by name and album
X = [doc['name'] for doc in data]
Y = [doc['album'] for doc in data]

# %%
for i in range(5):
    print(Y[i], '|', X[i], '\n')
# Out:
# {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mcTU81TzQhprhouKaTkpq'}, 'href': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq', 'id': '1mcTU81TzQhprhouKaTkpq', 'name': 'Rauw Alejandro', 'type': 'artist', 'uri': 'spotify:artist:1mcTU81TzQhprhouKaTkpq'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/6E7Awtyx6opYTbPXx6ApzB'}, 'href': 'https://api.spotify.com/v1/albums/6E7Awtyx6opYTbPXx6ApzB', 'id': '6E7Awtyx6opYTbPXx6ApzB', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273f79b1ab5cd74db6a2d7c1fda', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02f79b1ab5cd74db6a2d7c1fda', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851f79b1ab5cd74db6a2d7c1fda', 'width': 64}], 'is_playable': True, 'name': 'PLAYA SATURNO', 'release_date': '2023-07-07', 'release_date_precision': 'day', 'total_tracks': 14, 'type': 'album', 'uri': 'spotify:a
# ...

# %%
# Dataframe to observe the time duration of first top 10 songs
df1 = pd.read_json("RAsongs.json")
df2 = df1.sort_values("duration_ms", ascending = False)
df2.head(10)
# Out:
#                                                album  \
# 7  {'album_type': 'single', 'artists': [{'externa...
# 8  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 0  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'single', 'artists': [{'externa...
# 9  {'album_type': 'single', 'artists': [{'externa...
#
#                                              artists  disc_number  \
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
# 8  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# ...

# %%
# Cast time duration from numeric to strig
df2["duration_ms"] = pd.to_numeric(df2["duration_ms"])
# Out:
#                                                album  \
# 7  {'album_type': 'single', 'artists': [{'externa...
# 8  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 0  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'single', 'artists': [{'externa...
# 9  {'album_type': 'single', 'artists': [{'externa...
#
#                                              artists  disc_number  \
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
# 8  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# ...

# %%
# Graph for visualization
lines = df2.plot.line(x='duration_ms', y='popularity')
